# %%
import numpy as np
import pandas as pd

# %%
# data = np.load('weight_sharing_xor2000.npz', allow_pickle=True)
# misclassified = data['miscl']
# classes = data['cl']
# weights = data['w']
# losses = data['l']
# activations = data['act']
# perfect_iters = data['pi']
# perfect_iters = np.array(perfect_iters, dtype=np.float)
# combs = first_level_combinations()

# %%
# print(f'Number of perfect classifiers: {len(perfect_iters) - np.sum(np.isnan(perfect_iters))}')
# perfect_iters[np.isnan(perfect_iters)] = np.inf
# sorted_index = np.argsort(perfect_iters)
# display(perfect_iters[sorted_index][:10])
# display(weights[sorted_index][:10])
# display(np.array(combs)[sorted_index][:10])

# %%
total_count = 0
# data2 = np.load(f'vanilla_nn/data/combs_iters2000.npz', allow_pickle=True)

counter = 0
for j in range(10):
    combinations, initializations, misclassified, classes, weights, biases, losses, activations, perfect_iters = \
        [], [], [], [], [], [], [], [], []
    for i in range(10):
        data = np.load(f'recursive_nn_vanilla/data/xor_iters2000_job{j*10+i}.npz', allow_pickle=True)
#         combinations += data2['comb'].tolist()
        initializations += data['initial'].tolist()
        misclassified += data['miscl'].tolist()
        classes += data['cl'].tolist()
        weights += data['w'].tolist()
        biases += data['b'].tolist()
        losses += data['l'].tolist()
        activations += data['act'].tolist()
        perfect_iters += data['pi'].tolist()
    counter += len(initializations)
    df = pd.DataFrame({'inits': initializations, 'misclass': misclassified, 'classes': classes,
                  'weights': weights, 'biases': biases, 'losses': losses, 'acts': activations, 'perfect_iters': perfect_iters})
    good_ones = df[df['perfect_iters'].notna()]
    print(df['perfect_iters'].notna().sum())
    mean_iters = good_ones.mean()['perfect_iters']
    median_iters = good_ones.median()['perfect_iters']
    print(100*'x')
    total_count+=len(good_ones.index)
print(total_count)
# Out:
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 0

# %%
    df['combs_tuple'] = [tuple(x) for x in df['combs']]
#     grouped = df.groupby('combs_tuple')
#     for key, item in grouped:
#         print(grouped.get_group(key), "\n\n")
    good_ones = df.groupby('combs_tuple').filter(lambda x: x['perfect_iters'].notna().all())
    good_ones['mean_iters'] = good_ones.groupby('combs_tuple').mean()['perfect_iters']
#     print(good_ones.groupby('combs_tuple').mean()['perfect_iters'])
    print(good_ones.groupby('combs_tuple').agg(['mean', 'median', 'min', 'max', len])['perfect_iters'])
#     print(good_ones.groupby('combs_tuple').min()['perfect_iters'])
#     print(good_ones.groupby('combs_tuple').first()['combs'] if len(good_ones['combs']) > 0 else "")
    print(100*'x')
    total_count+=len(good_ones.groupby('combs_tuple').first()['combs'].index)
print(total_count)

# %%
# print(f'Number of perfect classifiers: {len(perfect_iters) - np.sum(np.isnan(perfect_iters))}')
# perfect_iters[np.isnan(perfect_iters)] = np.inf
# sorted_index = np.argsort(perfect_iters)
# display(perfect_iters[sorted_index][:10])
# display(weights[sorted_index][:10])
# display(np.array(combs)[sorted_index][:10])

# %%
total_count = 0
data2 = np.load(f'data/combs_iters2000.npz', allow_pickle=True)

counter = 0
for j in range(10):
    combinations, initializations, misclassified, classes, weights, biases, losses, activations, perfect_iters = \
        [], [], [], [], [], [], [], [], []
    for i in range(10):
        data = np.load(f'data/xor_iters2000_job{j*10+i}.npz', allow_pickle=True)
#         combinations += data2['comb'].tolist()
        initializations += data['initial'].tolist()
        misclassified += data['miscl'].tolist()
        classes += data['cl'].tolist()
        weights += data['w'].tolist()
        biases += data['b'].tolist()
        losses += data['l'].tolist()
        activations += data['act'].tolist()
        perfect_iters += data['pi'].tolist()
    combinations = data2['combs'].tolist()[counter:counter+len(initializations)]
    counter += len(initializations)
    df = pd.DataFrame({'combs': combinations, 'inits': initializations, 'misclass': misclassified, 'classes': classes,
                  'weights': weights, 'biases': biases, 'losses': losses, 'acts': activations, 'perfect_iters': perfect_iters})
    df['combs_tuple'] = [tuple(x) for x in df['combs']]
#     grouped = df.groupby('combs_tuple')
#     for key, item in grouped:
#         print(grouped.get_group(key), "\n\n")
    good_ones = df.groupby('combs_tuple').apply(lambda x: x['perfect_iters'].notna().sum() / len(x['perfect_iters'].index))
    print(good_ones > 0.57)
    print((good_ones > 0.57).sum())
    total_count += (good_ones > 0.57).sum()
    print(100*'x')
print(total_count)

# %%
total_count = 0
data2 = np.load(f'data/combs_iters2000.npz', allow_pickle=True)

counter = 0
for j in range(10):
    combinations, initializations, misclassified, classes, weights, biases, losses, activations, perfect_iters = \
        [], [], [], [], [], [], [], [], []
    for i in range(10):
        data = np.load(f'data/xor_iters2000_job{j*10+i}.npz', allow_pickle=True)
#         combinations += data2['comb'].tolist()
        initializations += data['initial'].tolist()
        misclassified += data['miscl'].tolist()
        classes += data['cl'].tolist()
        weights += data['w'].tolist()
        biases += data['b'].tolist()
        losses += data['l'].tolist()
        activations += data['act'].tolist()
        perfect_iters += data['pi'].tolist()
    combinations = data2['combs'].tolist()[counter:counter+len(initializations)]
    counter += len(initializations)
    df = pd.DataFrame({'combs': combinations, 'inits': initializations, 'misclass': misclassified, 'classes': classes,
                  'weights': weights, 'biases': biases, 'losses': losses, 'acts': activations, 'perfect_iters': perfect_iters})
    df['combs_tuple'] = [tuple(x) for x in df['combs']]
#     grouped = df.groupby('combs_tuple')
#     for key, item in grouped:
#         print(grouped.get_group(key), "\n\n")
    good_ones = df.groupby('combs_tuple').apply(lambda x: x['perfect_iters'].notna().sum() / len(x['perfect_iters'].index))
    print(good_ones > 0.57)
    print((good_ones > 0.57).sum())
    total_count += (good_ones > 0.57).sum()
    print(100*'x')
print(total_count)
# Out:
# combs_tuple
# (1, -1, -1, -1, -1, -1)    False
# (1, -1, -1, -1, -1, 1)     False
# (1, -1, -1, -1, -1, 2)     False
# (1, -1, -1, -1, 1, -1)     False
# (1, -1, -1, -1, 1, 1)      False
#                            ...
# (1, 2, 1, 1, 2, 2)         False
# (1, 2, 1, 2, -1, -1)       False
# (1, 2, 1, 2, -1, 1)        False
# (1, 2, 1, 2, 1, -1)        False
# (1, 2, 1, 2, 1, 1)         False
# Length: 350, dtype: bool
# 20
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, -1, -1, -1, 2, 3)    False
# (1, -1, -1, 1, 2, 3)     False
# (1, -1, -1, 2, -2, 3)    False
# (1, -1, -1, 2, -1, 3)    False
# (1, -1, -1, 2, 1, 3)     False
#                          ...
# (1, 2, 2, 2, 1, 2)       False
# (1, 2, 2, 2, 2, -2)      False
# (1, 2, 2, 2, 2, -1)      False
# (1, 2, 2, 2, 2, 1)       False
# (1, 2, 2, 2, 2, 2)       False
# Length: 300, dtype: bool
# 20
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, -1, 2, -2, 3, -3)    False
# (1, -1, 2, -2, 3, 3)     False
# (1, -1, 2, 2, 3, -3)     False
# (1, -1, 2, 2, 3, 3)      False
# (1, -1, 2, 3, -3, -3)     True
#                          ...
# (1, 2, 2, 1, -1, 3)      False
# (1, 2, 2, 1, 1, 3)       False
# (1, 2, 2, 1, 2, 3)       False
# (1, 2, 2, 1, 3, -1)      False
# (1, 2, 2, 1, 3, 1)       False
# Length: 250, dtype: bool
# 27
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, 2, -2, -2, -2, 3)    False
# (1, 2, -2, -2, -1, 3)    False
# (1, 2, -2, -2, 1, 3)     False
# (1, 2, -2, -2, 2, 3)     False
# (1, 2, -2, -2, 3, -3)    False
#                          ...
# (1, 2, 3, 1, 3, -2)      False
# (1, 2, 3, 1, 3, -1)      False
# (1, 2, 3, 1, 3, 1)       False
# (1, 2, 3, 1, 3, 2)       False
# (1, 2, 3, 1, 3, 3)       False
# Length: 200, dtype: bool
# 24
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, 1, -1, 2, 3, 4)      False
# (1, 1, 1, 2, 3, 4)       False
# (1, 2, 3, -3, -3, -3)     True
# (1, 2, 3, -3, -3, -2)     True
# (1, 2, 3, -3, -3, -1)    False
#                          ...
# (1, 2, 3, 3, 3, -2)       True
# (1, 2, 3, 3, 3, -1)      False
# (1, 2, 3, 3, 3, 1)       False
# (1, 2, 3, 3, 3, 2)       False
# (1, 2, 3, 3, 3, 3)        True
# Length: 150, dtype: bool
# 27
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, -1, -1, 2, 3, 4)    False
# (1, -1, 1, 2, 3, 4)     False
# (1, -1, 2, -2, 3, 4)    False
# (1, -1, 2, -1, 3, 4)    False
# (1, -1, 2, 1, 3, 4)     False
#                         ...
# (1, 2, 2, 3, 3, 4)      False
# (1, 2, 2, 3, 4, -2)     False
# (1, 2, 2, 3, 4, -1)     False
# (1, 2, 2, 3, 4, 1)      False
# (1, 2, 2, 3, 4, 2)      False
# Length: 100, dtype: bool
# 5
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, 2, -2, 3, 4, -4)    False
# (1, 2, -2, 3, 4, -3)    False
# (1, 2, -2, 3, 4, -2)    False
# (1, 2, -2, 3, 4, 2)     False
# (1, 2, -2, 3, 4, 3)     False
#                         ...
# (1, 2, 3, 3, 1, 4)       True
# (1, 2, 3, 3, 2, 4)      False
# (1, 2, 3, 3, 3, 4)      False
# (1, 2, 3, 3, 4, -1)     False
# (1, 2, 3, 3, 4, 1)      False
# Length: 80, dtype: bool
# 2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, 2, 3, -3, 4, -4)    False
# (1, 2, 3, -3, 4, -3)     True
# (1, 2, 3, -3, 4, -2)    False
# (1, 2, 3, -3, 4, -1)    False
# (1, 2, 3, -3, 4, 1)     False
# (1, 2, 3, -3, 4, 2)     False
# (1, 2, 3, -3, 4, 3)     False
# (1, 2, 3, -3, 4, 4)     False
# (1, 2, 3, 3, 4, -4)     False
# (1, 2, 3, 3, 4, -3)     False
# (1, 2, 3, 3, 4, -2)     False
# (1, 2, 3, 3, 4, 2)      False
# (1, 2, 3, 3, 4, 3)       True
# (1, 2, 3, 3, 4, 4)      False
# (1, 2, 3, 4, -3, -1)    False
# (1, 2, 3, 4, -3, 1)     False
# (1, 2, 3, 4, -2, -4)    False
# (1, 2, 3, 4, -2, -3)    False
# (1, 2, 3, 4, -2, -2)    False
# (1, 2, 3, 4, -2, -1)    False
# (1, 2, 3, 4, -2, 1)     False
# (1, 2, 3, 4, -2, 2)     False
# (1, 2, 3, 4, -2, 3)      True
# (1, 2, 3, 4, -2, 4)      True
# (1, 2, 3, 4, -1, -4)    False
# (1, 2, 3, 4, -1, -3)    False
# (1, 2, 3, 4, -1, -2)    False
# (1, 2, 3, 4, -1, -1)    False
# (1, 2, 3, 4, -1, 1)     False
# (1, 2, 3, 4, -1, 2)     False
# (1, 2, 3, 4, -1, 3)     False
# (1, 2, 3, 4, -1, 4)      True
# (1, 2, 3, 4, 1, -4)      True
# (1, 2, 3, 4, 1, -3)     False
# (1, 2, 3, 4, 1, -2)      True
# (1, 2, 3, 4, 1, -1)     False
# (1, 2, 3, 4, 1, 1)      False
# (1, 2, 3, 4, 1, 2)      False
# (1, 2, 3, 4, 1, 3)      False
# (1, 2, 3, 4, 1, 4)      False
# (1, 2, 3, 4, 2, -4)      True
# (1, 2, 3, 4, 2, -3)      True
# (1, 2, 3, 4, 2, -2)     False
# (1, 2, 3, 4, 2, -1)     False
# (1, 2, 3, 4, 2, 1)      False
# (1, 2, 3, 4, 2, 2)      False
# (1, 2, 3, 4, 2, 3)      False
# (1, 2, 3, 4, 2, 4)      False
# (1, 2, 3, 4, 3, -1)     False
# (1, 2, 3, 4, 3, 1)      False
# dtype: bool
# 9
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, -1, 2, 3, 4, 5)     False
# (1, 1, 2, 3, 4, 5)       True
# (1, 2, 3, 4, -4, -4)    False
# (1, 2, 3, 4, -4, -3)    False
# (1, 2, 3, 4, -4, -2)    False
# (1, 2, 3, 4, -4, -1)    False
# (1, 2, 3, 4, -4, 1)     False
# (1, 2, 3, 4, -4, 2)     False
# (1, 2, 3, 4, -4, 3)      True
# (1, 2, 3, 4, -4, 4)     False
# (1, 2, 3, 4, -3, -4)    False
# (1, 2, 3, 4, -3, -3)    False
# (1, 2, 3, 4, -3, -2)    False
# (1, 2, 3, 4, -3, 2)     False
# (1, 2, 3, 4, -3, 3)     False
# (1, 2, 3, 4, -3, 4)     False
# (1, 2, 3, 4, 3, -4)     False
# (1, 2, 3, 4, 3, -3)     False
# (1, 2, 3, 4, 3, -2)     False
# (1, 2, 3, 4, 3, 2)      False
# (1, 2, 3, 4, 3, 3)      False
# (1, 2, 3, 4, 3, 4)      False
# (1, 2, 3, 4, 4, -4)     False
# (1, 2, 3, 4, 4, -3)     False
# (1, 2, 3, 4, 4, -2)     False
# (1, 2, 3, 4, 4, -1)     False
# (1, 2, 3, 4, 4, 1)      False
# (1, 2, 3, 4, 4, 2)      False
# (1, 2, 3, 4, 4, 3)      False
# (1, 2, 3, 4, 4, 4)      False
# dtype: bool
# 2
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# combs_tuple
# (1, 2, -2, 3, 4, 5)    False
# (1, 2, -1, 3, 4, 5)    False
# (1, 2, 1, 3, 4, 5)     False
# (1, 2, 2, 3, 4, 5)     False
# (1, 2, 3, -3, 4, 5)    False
# (1, 2, 3, -2, 4, 5)    False
# (1, 2, 3, -1, 4, 5)    False
# (1, 2, 3, 1, 4, 5)     False
# (1, 2, 3, 2, 4, 5)     False
# (1, 2, 3, 3, 4, 5)      True
# (1, 2, 3, 4, -4, 5)    False
# (1, 2, 3, 4, -3, 5)    False
# (1, 2, 3, 4, -2, 5)    False
# (1, 2, 3, 4, -1, 5)    False
# (1, 2, 3, 4, 1, 5)      True
# (1, 2, 3, 4, 2, 5)      True
# (1, 2, 3, 4, 3, 5)     False
# (1, 2, 3, 4, 4, 5)     False
# (1, 2, 3, 4, 5, -5)    False
# (1, 2, 3, 4, 5, -4)    False
# (1, 2, 3, 4, 5, -3)    False
# (1, 2, 3, 4, 5, -2)    False
# (1, 2, 3, 4, 5, -1)    False
# (1, 2, 3, 4, 5, 1)     False
# (1, 2, 3, 4, 5, 2)     False
# (1, 2, 3, 4, 5, 3)      True
# (1, 2, 3, 4, 5, 4)      True
# (1, 2, 3, 4, 5, 5)     False
# dtype: bool
# 5
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 141
